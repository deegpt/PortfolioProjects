# %% [markdown]
# ### Objective

# %% [raw]
# The goal of this project using SQL would be to identify the opprotunities to increase the occupamcy rate on low-performing flights, which can ultimately lead to increased profitability for the airline.

# %%
import sqlite3
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Database Connection

# %%
connection = sqlite3.connect('travel.sqlite')
cursor = connection.cursor()

# %%
cursor.execute("""select name from sqlite_master where type='table';""")
print('List of table present in the database')
table_list = [table[0] for table in cursor.fetchall()]
table_list
# Out:
# List of table present in the database
# ['aircrafts_data',
#  'airports_data',
#  'boarding_passes',
#  'bookings',
#  'flights',
#  'seats',
#  'ticket_flights',
#  'tickets']

# %% [markdown]
# ### Data Exploration

# %%
aircrafts_data = pd.read_sql_query("select * from aircrafts_data", connection)
aircrafts_data
# Out:
#   aircraft_code                                              model  range
# 0           773    {"en": "Boeing 777-300", "ru": "Боинг 777-300"}  11100
# 1           763    {"en": "Boeing 767-300", "ru": "Боинг 767-300"}   7900
# 2           SU9  {"en": "Sukhoi Superjet-100", "ru": "Сухой Суп...   3000
# 3           320  {"en": "Airbus A320-200", "ru": "Аэробус A320-...   5700
# 4           321  {"en": "Airbus A321-200", "ru": "Аэробус A321-...   5600
# 5           319  {"en": "Airbus A319-100", "ru": "Аэробус A319-...   6700
# 6           733    {"en": "Boeing 737-300", "ru": "Боинг 737-300"}   4200
# 7           CN1  {"en": "Cessna 208 Caravan", "ru": "Сессна 208...   1200
# 8           CR2  {"en": "Bombardier CRJ-200", "ru": "Бомбардье ...   2700

# %%
airports_data = pd.read_sql_query("select * from airports_data", connection)
airports_data
# Out:
#     airport_code                                       airport_name  \
# 0            YKS          {"en": "Yakutsk Airport", "ru": "Якутск"}
# 1            MJZ            {"en": "Mirny Airport", "ru": "Мирный"}
# 2            KHV  {"en": "Khabarovsk-Novy Airport", "ru": "Хабар...
# 3            PKC        {"en": "Yelizovo Airport", "ru": "Елизово"}
# 4            UUS  {"en": "Yuzhno-Sakhalinsk Airport", "ru": "Хом...
# ..           ...                                                ...
# 99           MMK       {"en": "Murmansk Airport", "ru": "Мурманск"}
# 100          ABA           {"en": "Abakan Airport", "ru": "Абакан"}
# 101          BAX         {"en": "Barnaul Airport", "ru": "Барнаул"}
# 102          AAQ  {"en": "Anapa Vityazevo Airport", "ru": "Витяз...
# 103          CNN         {"en": "Chulman Airport", "ru": "Чульман"}
#
#                                                   city  \
# 0                    {"en": "Yakutsk", "ru": "Якутск"}
# ...

# %%
boarding_passes = pd.read_sql_query("select * from boarding_passes", connection)
boarding_passes
# Out:
#             ticket_no  flight_id  boarding_no seat_no
# 0       0005435212351      30625            1      2D
# 1       0005435212386      30625            2      3G
# 2       0005435212381      30625            3      4H
# 3       0005432211370      30625            4      5D
# 4       0005435212357      30625            5     11A
# ...               ...        ...          ...     ...
# 579681  0005434302871      19945           85     20F
# 579682  0005432892791      19945           86     21C
# 579683  0005434302869      19945           87     20E
# 579684  0005432802476      19945           88     21F
# 579685  0005432802482      19945           89     21E
#
# [579686 rows x 4 columns]

# %%
bookings = pd.read_sql_query("select * from bookings", connection)
bookings
# Out:
#        book_ref               book_date  total_amount
# 0        00000F  2017-07-05 03:12:00+03        265700
# 1        000012  2017-07-14 09:02:00+03         37900
# 2        000068  2017-08-15 14:27:00+03         18100
# 3        000181  2017-08-10 13:28:00+03        131800
# 4        0002D8  2017-08-07 21:40:00+03         23600
# ...         ...                     ...           ...
# 262783   FFFEF3  2017-07-17 07:23:00+03         56000
# 262784   FFFF2C  2017-08-08 05:55:00+03         10800
# 262785   FFFF43  2017-07-20 20:42:00+03         78500
# 262786   FFFFA8  2017-08-08 04:45:00+03         28800
# 262787   FFFFF7  2017-07-01 22:12:00+03         73600
#
# [262788 rows x 3 columns]

# %%
flights = pd.read_sql_query("select * from flights", connection)
flights
# Out:
#        flight_id flight_no     scheduled_departure       scheduled_arrival  \
# 0           1185    PG0134  2017-09-10 09:50:00+03  2017-09-10 14:55:00+03
# 1           3979    PG0052  2017-08-25 14:50:00+03  2017-08-25 17:35:00+03
# 2           4739    PG0561  2017-09-05 12:30:00+03  2017-09-05 14:15:00+03
# 3           5502    PG0529  2017-09-12 09:50:00+03  2017-09-12 11:20:00+03
# 4           6938    PG0461  2017-09-04 12:25:00+03  2017-09-04 13:20:00+03
# ...          ...       ...                     ...                     ...
# 33116      33117    PG0063  2017-08-02 19:25:00+03  2017-08-02 20:10:00+03
# 33117      33118    PG0063  2017-07-28 19:25:00+03  2017-07-28 20:10:00+03
# 33118      33119    PG0063  2017-09-08 19:25:00+03  2017-09-08 20:10:00+03
# 33119      33120    PG0063  2017-08-01 19:25:00+03  2017-08-01 20:10:00+03
# 33120      33121    PG0063  2017-08-26 19:25:00+03  2017-08-26 20:10:00+03
#
#       departure_airport arrival_airport     status aircraft_code  \
# ...

# %%
seats = pd.read_sql_query("select * from seats", connection)
seats
# Out:
#      aircraft_code seat_no fare_conditions
# 0              319      2A        Business
# 1              319      2C        Business
# 2              319      2D        Business
# 3              319      2F        Business
# 4              319      3A        Business
# ...            ...     ...             ...
# 1334           773     48H         Economy
# 1335           773     48K         Economy
# 1336           773     49A         Economy
# 1337           773     49C         Economy
# 1338           773     49D         Economy
#
# [1339 rows x 3 columns]

# %%
ticket_flights = pd.read_sql_query("select * from ticket_flights", connection)
ticket_flights
# Out:
#              ticket_no  flight_id fare_conditions  amount
# 0        0005432159776      30625        Business   42100
# 1        0005435212351      30625        Business   42100
# 2        0005435212386      30625        Business   42100
# 3        0005435212381      30625        Business   42100
# 4        0005432211370      30625        Business   42100
# ...                ...        ...             ...     ...
# 1045721  0005435097522      32094         Economy    5200
# 1045722  0005435097521      32094         Economy    5200
# 1045723  0005435104384      32094         Economy    5200
# 1045724  0005435104352      32094         Economy    5200
# 1045725  0005435104389      32094         Economy    5200
#
# [1045726 rows x 4 columns]

# %%
tickets = pd.read_sql_query("select * from tickets", connection)
tickets
# Out:
#             ticket_no book_ref passenger_id
# 0       0005432000987   06B046  8149 604011
# 1       0005432000988   06B046  8499 420203
# 2       0005432000989   E170C3  1011 752484
# 3       0005432000990   E170C3  4849 400049
# 4       0005432000991   F313DD  6615 976589
# ...               ...      ...          ...
# 366728  0005435999869   D730BA  0474 690760
# 366729  0005435999870   D730BA  6535 751108
# 366730  0005435999871   A1AD46  1596 156448
# 366731  0005435999872   7B6A53  9374 822707
# 366732  0005435999873   7B6A53  7380 075822
#
# [366733 rows x 3 columns]

# %%
# find the data types of columns in the table

for table in table_list:
    print('\nTable: ', table)
    column_info = connection.execute("PRAGMA table_info({})".format(table))  # PRAGMA is used when need to find table info
    for column in column_info.fetchall():
        print(column[1:3])
# Out:
# Table:  aircrafts_data
# ('aircraft_code', 'character(3)')
# ('model', 'jsonb')
# ('range', 'INTEGER')
#
# Table:  airports_data
# ('airport_code', 'character(3)')
# ('airport_name', 'jsonb')
# ('city', 'jsonb')
# ('coordinates', 'point')
# ('timezone', 'TEXT')
#
# Table:  boarding_passes
# ('ticket_no', 'character(13)')
# ('flight_id', 'INTEGER')
# ('boarding_no', 'INTEGER')
# ('seat_no', 'character varying(4)')
#
# Table:  bookings
# ('book_ref', 'character(6)')
# ('book_date', 'timestamp with time zone')
# ('total_amount', 'numeric(10,2)')
#
# Table:  flights
# ('flight_id', 'INTEGER')
# ('flight_no', 'character(6)')
# ('scheduled_departure', 'timestamp with time zone')
# ('scheduled_arrival', 'timestamp with time zone')
# ('departure_airport', 'character(3)')
# ('arrival_airport', 'character(3)')
# ('status', 'character varying(20)')
# ('aircraft_code', 'character(3)')
# ('actual_departure', 'timestamp with time zone')
# ('actual_arrival', 'timestamp with time zone')
#
# ...

# %% [raw]
# Find the missing values in the tables

# %%
for table in table_list:
    print('\nTable: ', table)
    df_table = pd.read_sql_query(f'select * from {table}', connection)
    print(df_table.isnull().sum())
# Out:
# Table:  aircrafts_data
# aircraft_code    0
# model            0
# range            0
# dtype: int64
#
# Table:  airports_data
# airport_code    0
# airport_name    0
# city            0
# coordinates     0
# timezone        0
# dtype: int64
#
# Table:  boarding_passes
# ticket_no      0
# flight_id      0
# boarding_no    0
# seat_no        0
# dtype: int64
#
# Table:  bookings
# book_ref        0
# book_date       0
# total_amount    0
# dtype: int64
#
# Table:  flights
# flight_id              0
# flight_no              0
# scheduled_departure    0
# scheduled_arrival      0
# departure_airport      0
# arrival_airport        0
# status                 0
# aircraft_code          0
# actual_departure       0
# actual_arrival         0
# dtype: int64
#
# Table:  seats
# aircraft_code      0
# seat_no            0
# fare_conditions    0
# dtype: int64
#
# Table:  ticket_flights
# ticket_no          0
# flight_id          0
# fare_conditions    0
# amount             0
# dtype: int64
# ...

# %% [markdown]
# ### Basic Analysis

# %% [markdown]
# #### 1. How many planes have more than 100 seats?

# %%
pd.read_sql_query("""select aircraft_code, count(*) as num_seats from seats
                     group by aircraft_code having num_seats > 100""", connection)
# Out:
#   aircraft_code  num_seats
# 0           319        116
# 1           320        140
# 2           321        170
# 3           733        130
# 4           763        222
# 5           773        402

# %% [markdown]
# #### 2. How the number of tickets booked and total amount earned changed with time?

# %%
# To find the tickets booked and the respective amounts charged, we can join the tickets and the bokings table.abs

booked_tickets = pd.read_sql_query("""select * from tickets inner join bookings
                    on tickets.book_ref = bookings.book_ref""", connection)
booked_tickets.dtypes
# Out:
# ticket_no       object
# book_ref        object
# passenger_id    object
# book_ref        object
# book_date       object
# total_amount     int64
# dtype: object

# %%
# Change the book_date dtpe to date-time

booked_tickets['book_date'] = pd.to_datetime(booked_tickets['book_date'])
booked_tickets.dtypes
# Out:
# ticket_no                          object
# book_ref                           object
# passenger_id                       object
# book_ref                           object
# book_date       datetime64[ns, UTC+03:00]
# total_amount                        int64
# dtype: object

# %%
# We'd only need the date and not the time from the book_date column to perform group by on date to find the
# avg tickets booked per day

booked_tickets['date'] = booked_tickets['book_date'].dt.time
booked_tickets
# Out:
#             ticket_no book_ref passenger_id book_ref  \
# 0       0005432000987   06B046  8149 604011   06B046
# 1       0005432000988   06B046  8499 420203   06B046
# 2       0005432000989   E170C3  1011 752484   E170C3
# 3       0005432000990   E170C3  4849 400049   E170C3
# 4       0005432000991   F313DD  6615 976589   F313DD
# ...               ...      ...          ...      ...
# 366728  0005435999869   D730BA  0474 690760   D730BA
# 366729  0005435999870   D730BA  6535 751108   D730BA
# 366730  0005435999871   A1AD46  1596 156448   A1AD46
# 366731  0005435999872   7B6A53  9374 822707   7B6A53
# 366732  0005435999873   7B6A53  7380 075822   7B6A53
#
#                        book_date  total_amount      date
# 0      2017-07-05 20:19:00+03:00         12400  20:19:00
# 1      2017-07-05 20:19:00+03:00         12400  20:19:00
# 2      2017-06-29 01:55:00+03:00         24700  01:55:00
# 3      2017-06-29 01:55:00+03:00         24700  01:55:00
# ...

# %%
booked_tickets.groupby('date')[['date']].count()
# Out:
#             date
# date
# 2017-06-21     6
# 2017-06-22    12
# 2017-06-23    28
# 2017-06-24   106
# 2017-06-25   266
# 2017-06-26   499
# 2017-06-27  1028
# 2017-06-28  1678
# 2017-06-29  2765
# 2017-06-30  3772
# 2017-07-01  4936
# 2017-07-02  5780
# 2017-07-03  6686
# 2017-07-04  7112
# 2017-07-05  7484
# 2017-07-06  7656
# 2017-07-07  7722
# 2017-07-08  7586
# 2017-07-09  7860
# 2017-07-10  7749
# 2017-07-11  7852
# 2017-07-12  7691
# 2017-07-13  7641
# 2017-07-14  7932
# 2017-07-15  7668
# 2017-07-16  7896
# 2017-07-17  7546
# 2017-07-18  7745
# 2017-07-19  7821
# 2017-07-20  7637
# 2017-07-21  7771
# 2017-07-22  7698
# 2017-07-23  7627
# 2017-07-24  7667
# 2017-07-25  7826
# 2017-07-26  7730
# 2017-07-27  7636
# 2017-07-28  7827
# 2017-07-29  7588
# 2017-07-30  7732
# 2017-07-31  7653
# 2017-08-01  7740
# 2017-08-02  7669
# 2017-08-03  7756
# 2017-08-04  7908
# 2017-08-05  8064
# 2017-08-06  8016
# 2017-08-07  7910
# 2017-08-08  8153
# 2017-08-09  8258
# 2017-08-10  8493
# ...

# %%
# Plot the num of tickets booked per day in a line graph

x = booked_tickets.groupby('date')[['date']].count()
plt.figure(figsize=(18,6))
plt.plot(x.index, x['date'], marker = '^')
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Number of tickets', fontsize=20)
plt.grid('b')
plt.show()

# %% [raw]
# 8000 tickets are booked per day in an average and may be due to some festive seaason in August it suddenly spiked to 10000 and then dropped insignificantly.

# %%
# Plot the line graph for the total amounts earned

bookings = pd.read_sql_query("""select * from bookings""", connection)
bookings['book_date'] = pd.to_datetime(bookings['book_date'])
bookings['date'] = bookings['book_date'].dt.date

x = bookings.groupby('date')[['total_amount']].sum()
plt.figure(figsize=(18,6))
plt.plot(x.index, x['total_amount'], marker = '^')
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Total amount earned', fontsize=20)
plt.grid('b')
plt.show()

# %% [raw]
# Both of the graphs are almost similar in trends, thus we can say that the number of tickets booked are relative to the total amount earned.

# %% [markdown]
# #### 3. Calculate the average charges for each aircraft with different fare conditions.

# %% [raw]
# For this, we will have to find the tables that contains amount, aircraft code and fare conditions, if not, we can join the tables.
#
# Table flights does have the flight_id and the aircraft_code and the table ticket_flights have the flight_id and the fare_conditions, so joining them.

# %%
df = pd.read_sql_query("""select * from ticket_flights join flights 
                     on ticket_flights.flight_id = flights.flight_id""", connection)
df
# Out:
#              ticket_no  flight_id fare_conditions  amount  flight_id  \
# 0        0005432159776      30625        Business   42100      30625
# 1        0005435212351      30625        Business   42100      30625
# 2        0005435212386      30625        Business   42100      30625
# 3        0005435212381      30625        Business   42100      30625
# 4        0005432211370      30625        Business   42100      30625
# ...                ...        ...             ...     ...        ...
# 1045721  0005435097522      32094         Economy    5200      32094
# 1045722  0005435097521      32094         Economy    5200      32094
# 1045723  0005435104384      32094         Economy    5200      32094
# 1045724  0005435104352      32094         Economy    5200      32094
# 1045725  0005435104389      32094         Economy    5200      32094
#
#         flight_no     scheduled_departure       scheduled_arrival  \
# 0          PG0013  2017-07-16 18:15:00+03  2017-07-16 20:00:00+03
# ...

# %%
df = pd.read_sql_query("""select fare_conditions, aircraft_code, avg(amount) avg_amount 
                          from ticket_flights join flights 
                          on ticket_flights.flight_id = flights.flight_id
                          group by aircraft_code, fare_conditions""", connection)
df
# Out:
#    fare_conditions aircraft_code     avg_amount
# 0         Business           319  113550.557703
# 1          Economy           319   38311.402347
# 2         Business           321   34435.662664
# 3          Economy           321   11534.974764
# 4         Business           733   41865.626175
# 5          Economy           733   13985.152000
# 6         Business           763   82839.842866
# 7          Economy           763   27594.721829
# 8         Business           773   57779.909435
# 9          Comfort           773   32740.552889
# 10         Economy           773   19265.225693
# 11         Economy           CN1    6568.552345
# 12         Economy           CR2   13207.661102
# 13        Business           SU9   33487.849829
# 14         Economy           SU9   11220.183400

# %%
# Plot the barchart to find the avg_amount in diff fare-conditios for each aaircrafts_data to compare the prices.

sns.barplot(data = df, x = 'aircraft_code', y = 'avg_amount', hue = 'fare_conditions')
# Out:
# <Axes: xlabel='aircraft_code', ylabel='avg_amount'>

# %% [raw]
# With this visualization we can conlude that the aircraft 773 has only the comfort class in it. The aircraft 319 has the highest prices for business class and economy class comparatively.

# %% [markdown]
# ### Analyzing Occupancy Rate

# %% [markdown]
# #### 1. For each aircraft, calculate the total revenue per year and the average revenue per ticket.

# %% [raw]
# Find the total revenue, ticket count, avg revenue per ticket = total revenue / ticket count
#
# Tables to be used: ticket_flights, flights

# %%
pd.read_sql_query("""select aircraft_code, ticket_count, Total_Revenue, Total_Revenue/ticket_count 'Avg_revenue_per_ticket' from
                     (select aircraft_code, count(*) ticket_count, sum(amount) Total_Revenue 
                     from ticket_flights join flights 
                     on ticket_flights.flight_id = flights.flight_id
                     group by aircraft_code)""", connection)
# Out:
#   aircraft_code  ticket_count  Total_Revenue  Avg_revenue_per_ticket
# 0           319         52853     2706163100                   51201
# 1           321        107129     1638164100                   15291
# 2           733         86102     1426552100                   16568
# 3           763        124774     4371277100                   35033
# 4           773        144376     3431205500                   23765
# 5           CN1         14672       96373800                    6568
# 6           CR2        150122     1982760500                   13207
# 7           SU9        365698     5114484700                   13985

# %% [markdown]
# #### 2. Calculate the average occupancy per aircraft.

# %% [raw]
# For finding the occupancy, we join the boarding passes table as it have seat_no. with boarding no. and the flights table.

# %%
occupancy_rate = pd.read_sql_query("""select a.aircraft_code, avg(a.seats_count) booked_seats, avg(a.seats_count)/b.num_seats occupancy_rate from
                     (select aircraft_code, f.flight_id, count(*) as seats_count from boarding_passes bp
                     join flights f
                     on f.flight_id = bp.flight_id
                     group by aircraft_code, f.flight_id) a
                     join
                     (select aircraft_code, count(*) num_seats from seats group by aircraft_code) b
                     on a.aircraft_code = b.aircraft_code
                     group by a.aircraft_code""", connection)
occupancy_rate
# Out:
#   aircraft_code  booked_seats  occupancy_rate
# 0           319     53.583181        0.461924
# 1           321     88.809231        0.522407
# 2           733     80.255462        0.617350
# 3           763    113.937294        0.513231
# 4           773    264.925806        0.659019
# 5           CN1      6.004431        0.500369
# 6           CR2     21.482847        0.429657
# 7           SU9     56.812113        0.585692

# %% [markdown]
# #### 3. Calculate by how much the total annual turnover could incrase by giving all aircraft a 10% higher
# ####        occupancy rate.

# %%
occupancy_rate['inc_occupancy_rate'] = occupancy_rate['occupancy_rate'] + occupancy_rate['occupancy_rate']*0.1
occupancy_rate
# Out:
#   aircraft_code  booked_seats  occupancy_rate  inc_occupancy_rate
# 0           319     53.583181        0.461924            0.508116
# 1           321     88.809231        0.522407            0.574648
# 2           733     80.255462        0.617350            0.679085
# 3           763    113.937294        0.513231            0.564554
# 4           773    264.925806        0.659019            0.724921
# 5           CN1      6.004431        0.500369            0.550406
# 6           CR2     21.482847        0.429657            0.472623
# 7           SU9     56.812113        0.585692            0.644261

# %%
total_revenue= pd.read_sql_query("""select aircraft_code, sum(amount) total_revenue from ticket_flights
                                     join flights on ticket_flights.flight_id = flights.flight_id
                                     group by aircraft_code""", connection)

occupancy_rate['Inc Total Annual Turnover'] = (total_revenue['total_revenue']/occupancy_rate['occupancy_rate'])*occupancy_rate['inc_occupancy_rate']

occupancy_rate
# Out:
#   aircraft_code  booked_seats  occupancy_rate  inc_occupancy_rate  \
# 0           319     53.583181        0.461924            0.508116
# 1           321     88.809231        0.522407            0.574648
# 2           733     80.255462        0.617350            0.679085
# 3           763    113.937294        0.513231            0.564554
# 4           773    264.925806        0.659019            0.724921
# 5           CN1      6.004431        0.500369            0.550406
# 6           CR2     21.482847        0.429657            0.472623
# 7           SU9     56.812113        0.585692            0.644261
#
#    Inc Total Annual Turnover
# 0               2.976779e+09
# 1               1.801981e+09
# 2               1.569207e+09
# 3               4.808405e+09
# 4               3.774326e+09
# 5               1.060112e+08
# 6               2.181037e+09
# 7               5.625933e+09

# %%
# To see the full value of the inc total annual turnover and other columns

pd.set_option('display.float_format', str)
occupancy_rate
# Out:
#   aircraft_code       booked_seats      occupancy_rate  inc_occupancy_rate  \
# 0           319  53.58318098720292 0.46192397402761143  0.5081163714303726
# 1           321  88.80923076923077  0.5224072398190045   0.574647963800905
# 2           733  80.25546218487395   0.617349709114415  0.6790846800258565
# 3           763 113.93729372937294  0.5132310528350132  0.5645541581185146
# 4           773  264.9258064516129   0.659019419033863  0.7249213609372492
# 5           CN1  6.004431314623338  0.5003692762186115  0.5504062038404727
# 6           CR2  21.48284690220174 0.42965693804403476  0.4726226318484382
# 7           SU9  56.81211267605634  0.5856918832583128   0.644261071584144
#
#    Inc Total Annual Turnover
# 0               2976779410.0
# 1               1801980510.0
# 2         1569207310.0000002
# 3               4808404810.0
# 4               3774326050.0
# 5         106011180.00000001
# 6               2181036550.0
# 7          5625933169.999999
